# %%
# @hidden_cell
# The project token is an authorization token that is used to access project resources like data sources, connections, and used by platform APIs.
from project_lib import Project
project = Project(project_id='95c715c2-d24f-497b-ae56-6a9b290ac257', project_access_token='p-7f0683f20016bc7f85652519e652faf250391508')
pc = project.project_context

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, r2_score, classification_report
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
# %matplotlib inline

# %% [markdown]
# <h1>Getting the dataset</h1>

# %%
df=pd.read_csv('https://s3.us.cloud-object-storage.appdomain.cloud/cf-courses-data/CognitiveClass/DP0701EN/version-2/Data-Collisions.csv')
df.head()
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (33) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    SEVERITYCODE           X          Y  OBJECTID  INCKEY  COLDETKEY REPORTNO  \
# 0             2 -122.323148  47.703140         1    1307       1307  3502005
# 1             1 -122.347294  47.647172         2   52200      52200  2607959
# 2             1 -122.334540  47.607871         3   26700      26700  1482393
# 3             1 -122.334803  47.604803         4    1144       1144  3503937
# 4             2 -122.306426  47.545739         5   17700      17700  1807429
#
#     STATUS      ADDRTYPE   INTKEY  ... ROADCOND                LIGHTCOND  \
# 0  Matched  Intersection  37475.0  ...      Wet                 Daylight
# 1  Matched         Block      NaN  ...      Wet  Dark - Street Lights On
# 2  Matched         Block      NaN  ...      Dry                 Daylight
# 3  Matched         Block      NaN  ...      Dry                 Daylight
# 4  Matched  Intersection  34387.0  ...      Wet                 Daylight
#
#   PEDROWNOTGRNT  SDOTCOLNUM SPEEDING ST_COLCODE  \
# 0           NaN         NaN      NaN         10
# 1           NaN   6354039.0      NaN         11
# 2           NaN   4323031.0      NaN         32
# 3           NaN         NaN      NaN         23
# 4           NaN   4028032.0      NaN         10
#
#                                           ST_COLDESC  SEGLANEKEY  \
# 0                                  Entering at angle           0
# 1  From same direction - both going straight - bo...           0
# 2                             One parked--one moving           0
# 3                   From same direction - all others           0
# 4                                  Entering at angle           0
#
#    CROSSWALKKEY  HITPARKEDCAR
# 0             0             N
# 1             0             N
# 2             0             N
# 3             0             N
# 4             0             N
#
# [5 rows x 38 columns]

# %%
df.shape
# Out:
# (194673, 38)

# %%
df = df[['SEVERITYCODE', 'X', 'Y',  'PERSONCOUNT',
       'PEDCOUNT', 'PEDCYLCOUNT', 'VEHCOUNT',
       'UNDERINFL', 'WEATHER', 'ROADCOND', 'LIGHTCOND']]
       
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194673 entries, 0 to 194672
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   SEVERITYCODE  194673 non-null  int64
#  1   X             189339 non-null  float64
#  2   Y             189339 non-null  float64
#  3   PERSONCOUNT   194673 non-null  int64
#  4   PEDCOUNT      194673 non-null  int64
#  5   PEDCYLCOUNT   194673 non-null  int64
#  6   VEHCOUNT      194673 non-null  int64
#  7   UNDERINFL     189789 non-null  object
#  8   WEATHER       189592 non-null  object
#  9   ROADCOND      189661 non-null  object
#  10  LIGHTCOND     189503 non-null  object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 16.3+ MB

# %%
def missing_function(df):
    missing_data = df.isnull()
    missing_data.head()

    for column in missing_data.columns.values.tolist():
        print(column)
        print(missing_data[column].value_counts())
        print(df[column].value_counts())
        print("")
        
missing_function(df)
# Out:
# SEVERITYCODE
# False    194673
# Name: SEVERITYCODE, dtype: int64
# 1    136485
# 2     58188
# Name: SEVERITYCODE, dtype: int64
#
# X
# False    189339
# True       5334
# Name: X, dtype: int64
# -122.332653    265
# -122.344896    254
# -122.328079    252
# -122.344997    239
# -122.299160    231
#               ...
# -122.322768      1
# -122.288680      1
# -122.405699      1
# -122.323578      1
# -122.343898      1
# Name: X, Length: 23563, dtype: int64
#
# Y
# False    189339
# True       5334
# Name: Y, dtype: int64
# 47.708655    265
# 47.717173    254
# 47.604161    252
# 47.725036    239
# 47.579673    231
#             ...
# 47.556705      1
# 47.709101      1
# 47.513899      1
# 47.565438      1
# 47.563521      1
# Name: Y, Length: 23839, dtype: int64
#
# PERSONCOUNT
# False    194673
# Name: PERSONCOUNT, dtype: int64
# 2     114231
# 3      35553
# 4      14660
# 1      13154
# 5       6584
# 0       5544
# 6       2702
# 7       1131
# 8        533
# 9        216
# 10       128
# 11        56
# 12        33
# 13        21
# 14        19
# 15        11
# 17        11
# 16         8
# 44         6
# 18         6
# 20         6
# 25         6
# 19         5
# 26         4
# 22         4
# 27         3
# 28         3
# 29         3
# 47         3
# 32         3
# 34         3
# 37         3
# 23         2
# 21         2
# 24         2
# 30         2
# 36         2
# 57         1
# 31         1
# 35         1
# 39         1
# 41         1
# 43         1
# 48         1
# 53         1
# 54         1
# 81         1
# Name: PERSONCOUNT, dtype: int64
#
# PEDCOUNT
# False    194673
# Name: PEDCOUNT, dtype: int64
# 0    187734
# 1      6685
# 2       226
# 3        22
# 4         4
# 6         1
# 5         1
# Name: PEDCOUNT, dtype: int64
#
# PEDCYLCOUNT
# False    194673
# Name: PEDCYLCOUNT, dtype: int64
# 0    189189
# 1      5441
# 2        43
# Name: PEDCYLCOUNT, dtype: int64
#
# VEHCOUNT
# False    194673
# Name: VEHCOUNT, dtype: int64
# 2     147650
# 1      25748
# 3      13010
# 0       5085
# 4       2426
# 5        529
# 6        146
# 7         46
# 8         15
# 9          9
# 11         6
# 10         2
# 12         1
# Name: VEHCOUNT, dtype: int64
#
# UNDERINFL
# False    189789
# True       4884
# Name: UNDERINFL, dtype: int64
# N    100274
# 0     80394
# Y      5126
# 1      3995
# Name: UNDERINFL, dtype: int64
#
# WEATHER
# False    189592
# True       5081
# Name: WEATHER, dtype: int64
# Clear                       111135
# Raining                      33145
# Overcast                     27714
# Unknown                      15091
# Snowing                        907
# Other                          832
# Fog/Smog/Smoke                 569
# Sleet/Hail/Freezing Rain       113
# Blowing Sand/Dirt               56
# Severe Crosswind                25
# Partly Cloudy                    5
# Name: WEATHER, dtype: int64
#
# ROADCOND
# False    189661
# True       5012
# Name: ROADCOND, dtype: int64
# Dry               124510
# Wet                47474
# Unknown            15078
# Ice                 1209
# Snow/Slush          1004
# Other                132
# Standing Water       115
# Sand/Mud/Dirt         75
# Oil                   64
# Name: ROADCOND, dtype: int64
#
# LIGHTCOND
# False    189503
# True       5170
# Name: LIGHTCOND, dtype: int64
# Daylight                    116137
# Dark - Street Lights On      48507
# Unknown                      13473
# Dusk                          5902
# Dawn                          2502
# Dark - No Street Lights       1537
# Dark - Street Lights Off      1199
# Other                          235
# Dark - Unknown Lighting         11
# Name: LIGHTCOND, dtype: int64

# %%
df.replace(r'^\s*$', np.nan, regex=True)
df.replace("Unknown", np.nan, inplace = True)
df.replace("Other", np.nan, inplace = True)


#removing rows for columns with less than 20% values missing (#UNDERINFL,WEATHER,ROADCOND,LIGHTCOND)
                                                            
df.dropna(subset=["X","Y","UNDERINFL","WEATHER","ROADCOND","LIGHTCOND"], 
          axis=0, inplace=True)

#making sure all missing values are handled with
print(df.info())
missing_function(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 166217 entries, 0 to 194672
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   SEVERITYCODE  166217 non-null  int64
#  1   X             166217 non-null  float64
#  2   Y             166217 non-null  float64
#  3   PERSONCOUNT   166217 non-null  int64
#  4   PEDCOUNT      166217 non-null  int64
#  5   PEDCYLCOUNT   166217 non-null  int64
#  6   VEHCOUNT      166217 non-null  int64
#  7   UNDERINFL     166217 non-null  object
#  8   WEATHER       166217 non-null  object
#  9   ROADCOND      166217 non-null  object
#  10  LIGHTCOND     166217 non-null  object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 15.2+ MB
# None
# SEVERITYCODE
# False    166217
# Name: SEVERITYCODE, dtype: int64
# 1    111503
# 2     54714
# Name: SEVERITYCODE, dtype: int64
#
# X
# False    166217
# Name: X, dtype: int64
# -122.332653    251
# -122.344896    240
# -122.328079    236
# -122.344997    224
# -122.299160    215
#               ...
# -122.263125      1
# -122.363333      1
# -122.391070      1
# -122.308963      1
# -122.306625      1
# Name: X, Length: 21946, dtype: int64
#
# Y
# False    166217
# Name: Y, dtype: int64
# 47.708655    251
# 47.717173    240
# 47.604161    236
# 47.725036    224
# 47.579673    215
#             ...
# 47.717236      1
# 47.664291      1
# 47.576882      1
# 47.626641      1
# 47.723089      1
# Name: Y, Length: 22187, dtype: int64
#
# PERSONCOUNT
# False    166217
# Name: PERSONCOUNT, dtype: int64
# 2     92220
# 3     33470
# 4     13943
# 1     10265
# 5      6354
# 0      5188
# 6      2620
# 7      1085
# 8       514
# 9       205
# 10      126
# 11       53
# 12       32
# 13       20
# 14       17
# 15       11
# 17       11
# 16        7
# 18        6
# 44        6
# 19        5
# 20        5
# 25        5
# 26        4
# 22        4
# 27        3
# 28        3
# 29        3
# 47        3
# 32        3
# 34        3
# 37        3
# 23        2
# 21        2
# 24        2
# 30        2
# 36        2
# 57        1
# 31        1
# 35        1
# 39        1
# 41        1
# 43        1
# 48        1
# 53        1
# 54        1
# 81        1
# Name: PERSONCOUNT, dtype: int64
#
# PEDCOUNT
# False    166217
# Name: PEDCOUNT, dtype: int64
# 0    159625
# 1      6344
# 2       220
# 3        22
# 4         4
# 6         1
# 5         1
# Name: PEDCOUNT, dtype: int64
#
# PEDCYLCOUNT
# False    166217
# Name: PEDCYLCOUNT, dtype: int64
# 0    160960
# 1      5215
# 2        42
# Name: PEDCYLCOUNT, dtype: int64
#
# VEHCOUNT
# False    166217
# Name: VEHCOUNT, dtype: int64
# 2     127198
# 1      23480
# 3      12307
# 4       2319
# 5        509
# 0        190
# 6        140
# 7         42
# 8         15
# 9          9
# 11         5
# 10         2
# 12         1
# Name: VEHCOUNT, dtype: int64
#
# UNDERINFL
# False    166217
# Name: UNDERINFL, dtype: int64
# N    87749
# 0    69724
# Y     4917
# 1     3827
# Name: UNDERINFL, dtype: int64
#
# WEATHER
# False    166217
# Name: WEATHER, dtype: int64
# Clear                       106752
# Raining                      31559
# Overcast                     26379
# Snowing                        813
# Fog/Smog/Smoke                 537
# Sleet/Hail/Freezing Rain       106
# Blowing Sand/Dirt               42
# Severe Crosswind                24
# Partly Cloudy                    5
# Name: WEATHER, dtype: int64
#
# ROADCOND
# False    166217
# Name: ROADCOND, dtype: int64
# Dry               119167
# Wet                44975
# Ice                 1055
# Snow/Slush           821
# Standing Water        94
# Sand/Mud/Dirt         56
# Oil                   49
# Name: ROADCOND, dtype: int64
#
# LIGHTCOND
# False    166217
# Name: LIGHTCOND, dtype: int64
# Daylight                    110315
# Dark - Street Lights On      45621
# Dusk                          5532
# Dawn                          2337
# Dark - No Street Lights       1333
# Dark - Street Lights Off      1071
# Dark - Unknown Lighting          8
# Name: LIGHTCOND, dtype: int64

# %%
df.head()
# Out:
#    SEVERITYCODE           X          Y  PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  \
# 0             2 -122.323148  47.703140            2         0            0
# 1             1 -122.347294  47.647172            2         0            0
# 2             1 -122.334540  47.607871            4         0            0
# 3             1 -122.334803  47.604803            3         0            0
# 4             2 -122.306426  47.545739            2         0            0
#
#    VEHCOUNT UNDERINFL   WEATHER ROADCOND                LIGHTCOND
# 0         2         N  Overcast      Wet                 Daylight
# 1         2         0   Raining      Wet  Dark - Street Lights On
# 2         3         0  Overcast      Dry                 Daylight
# 3         3         N     Clear      Dry                 Daylight
# 4         2         0   Raining      Wet                 Daylight

# %%
df.shape
# Out:
# (166217, 11)

# %%
df.describe(include='all')
# Out:
#          SEVERITYCODE              X              Y    PERSONCOUNT  \
# count   166217.000000  166217.000000  166217.000000  166217.000000
# unique            NaN            NaN            NaN            NaN
# top               NaN            NaN            NaN            NaN
# freq              NaN            NaN            NaN            NaN
# mean         1.329172    -122.330338      47.618942       2.511500
# std          0.469914       0.029813       0.056670       1.410457
# min          1.000000    -122.419032      47.495573       0.000000
# 25%          1.000000    -122.348172      47.574310       2.000000
# 50%          1.000000    -122.330276      47.614827       2.000000
# 75%          2.000000    -122.311937      47.663664       3.000000
# max          2.000000    -122.238949      47.734142      81.000000
#
#              PEDCOUNT    PEDCYLCOUNT       VEHCOUNT UNDERINFL WEATHER  \
# count   166217.000000  166217.000000  166217.000000    166217  166217
# unique            NaN            NaN            NaN         4       9
# top               NaN            NaN            NaN         N   Clear
# freq              NaN            NaN            NaN     87749  106752
# mean         0.041374       0.031880       1.973565       NaN     NaN
# std          0.209029       0.177114       0.576237       NaN     NaN
# min          0.000000       0.000000       0.000000       NaN     NaN
# 25%          0.000000       0.000000       2.000000       NaN     NaN
# 50%          0.000000       0.000000       2.000000       NaN     NaN
# 75%          0.000000       0.000000       2.000000       NaN     NaN
# max          6.000000       2.000000      12.000000       NaN     NaN
#
#        ROADCOND LIGHTCOND
# count    166217    166217
# unique        7         7
# top         Dry  Daylight
# freq     119167    110315
# mean        NaN       NaN
# std         NaN       NaN
# min         NaN       NaN
# 25%         NaN       NaN
# 50%         NaN       NaN
# 75%         NaN       NaN
# max         NaN       NaN

# %%
df['SEVERITYCODE'].value_counts()
# Out:
# 1    111503
# 2     54714
# Name: SEVERITYCODE, dtype: int64

# %%
#shuffling and creating a balanced dataset
df= df.sample(frac=1,random_state=0,replace=False)

# 1 - Put all severity code 2 class in a separate dataset.
df_scode2 = df.loc[df['SEVERITYCODE'] == 2]

# 2 - Randomly select 58188 observations from the severity code 1(majority class)
df_scode1 = df.loc[df['SEVERITYCODE'] == 1].sample(n=54714,random_state=42)

# 3 - concatenating datasets to get balanced dataset
df_balanced = pd.concat([df_scode1,df_scode2])
df_balanced = df_balanced.sample(frac=1,random_state=0,replace=False)

#Replacing 0 with N and 1 with Y as this column has mixed datatype values, making it consistent
df_balanced['UNDERINFL'] = df_balanced['UNDERINFL'].replace(['0'],'N')
df_balanced['UNDERINFL'] = df_balanced['UNDERINFL'].replace(['1'],'Y')

#checking if dataset balanced
print(df_balanced.info())
print(df_balanced['SEVERITYCODE'].value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 109428 entries, 9906 to 73787
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   SEVERITYCODE  109428 non-null  int64
#  1   X             109428 non-null  float64
#  2   Y             109428 non-null  float64
#  3   PERSONCOUNT   109428 non-null  int64
#  4   PEDCOUNT      109428 non-null  int64
#  5   PEDCYLCOUNT   109428 non-null  int64
#  6   VEHCOUNT      109428 non-null  int64
#  7   UNDERINFL     109428 non-null  object
#  8   WEATHER       109428 non-null  object
#  9   ROADCOND      109428 non-null  object
#  10  LIGHTCOND     109428 non-null  object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 10.0+ MB
# None
# 2    54714
# 1    54714
# Name: SEVERITYCODE, dtype: int64

# %%
df_balanced.head()
# Out:
#         SEVERITYCODE           X          Y  PERSONCOUNT  PEDCOUNT  \
# 9906               1 -122.347301  47.645030            2         0
# 119351             1 -122.356906  47.728233            2         0
# 75216              1 -122.279013  47.526117            2         0
# 24054              1 -122.310660  47.615378            2         0
# 82593              1 -122.300601  47.546379            5         0
#
#         PEDCYLCOUNT  VEHCOUNT UNDERINFL  WEATHER ROADCOND  \
# 9906              0         2         N  Raining      Wet
# 119351            0         2         N    Clear      Dry
# 75216             0         2         N    Clear      Dry
# 24054             0         2         N    Clear      Dry
# 82593             0         2         N    Clear      Dry
#
#                       LIGHTCOND
# 9906    Dark - Street Lights On
# 119351                 Daylight
# 75216                  Daylight
# 24054                  Daylight
# 82593                  Daylight

# %%
for column in df_balanced:
        print(column)
        print(df_balanced[column].value_counts())
# Out:
# SEVERITYCODE
# 2    54714
# 1    54714
# Name: SEVERITYCODE, dtype: int64
# X
# -122.344896    186
# -122.328079    174
# -122.332653    167
# -122.344997    155
# -122.299160    144
#               ...
# -122.398372      1
# -122.284939      1
# -122.337517      1
# -122.386214      1
# -122.360942      1
# Name: X, Length: 18567, dtype: int64
# Y
# 47.717173    186
# 47.604161    174
# 47.708655    167
# 47.725036    155
# 47.579673    144
#             ...
# 47.627977      1
# 47.698981      1
# 47.503160      1
# 47.534065      1
# 47.668090      1
# Name: Y, Length: 18749, dtype: int64
# PERSONCOUNT
# 2     58429
# 3     23026
# 4      9931
# 1      6451
# 5      4552
# 0      3440
# 6      1919
# 7       852
# 8       395
# 9       168
# 10       99
# 11       42
# 12       28
# 14       15
# 13       14
# 17       10
# 15        9
# 16        5
# 18        4
# 19        3
# 22        3
# 25        3
# 26        3
# 32        3
# 29        2
# 34        2
# 44        2
# 23        2
# 37        2
# 30        2
# 48        1
# 43        1
# 41        1
# 39        1
# 20        1
# 53        1
# 28        1
# 27        1
# 24        1
# 81        1
# 21        1
# 54        1
# Name: PERSONCOUNT, dtype: int64
# PEDCOUNT
# 0    103192
# 1      6001
# 2       207
# 3        22
# 4         4
# 6         1
# 5         1
# Name: PEDCOUNT, dtype: int64
# PEDCYLCOUNT
# 0    104464
# 1      4922
# 2        42
# Name: PEDCYLCOUNT, dtype: int64
# VEHCOUNT
# 2     79968
# 1     18347
# 3      8755
# 4      1647
# 5       377
# 0       188
# 6        99
# 7        25
# 9         8
# 8         7
# 11        4
# 10        2
# 12        1
# Name: VEHCOUNT, dtype: int64
# UNDERINFL
# N    103423
# Y      6005
# Name: UNDERINFL, dtype: int64
# WEATHER
# Clear                       70171
# Raining                     21028
# Overcast                    17287
# Snowing                       473
# Fog/Smog/Smoke                357
# Sleet/Hail/Freezing Rain       64
# Blowing Sand/Dirt              27
# Severe Crosswind               17
# Partly Cloudy                   4
# Name: WEATHER, dtype: int64
# ROADCOND
# Dry               78317
# Wet               29831
# Ice                 660
# Snow/Slush          487
# Standing Water       60
# Sand/Mud/Dirt        38
# Oil                  35
# Name: ROADCOND, dtype: int64
# LIGHTCOND
# Daylight                    73260
# Dark - Street Lights On     29443
# Dusk                         3687
# Dawn                         1546
# Dark - No Street Lights       821
# Dark - Street Lights Off      665
# Dark - Unknown Lighting         6
# Name: LIGHTCOND, dtype: int64

# %%
X = df_balanced.iloc[:,1:]

#Encoding Categorical Features - Training Dataset
X = pd.get_dummies(data=X, columns=['WEATHER','ROADCOND','LIGHTCOND','UNDERINFL'])
                                                            

Y = df_balanced['SEVERITYCODE'].values
print(X.head())
print(X.info())
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=0)
# Out:
#                  X          Y  PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  VEHCOUNT  \
# 9906   -122.347301  47.645030            2         0            0         2
# 119351 -122.356906  47.728233            2         0            0         2
# 75216  -122.279013  47.526117            2         0            0         2
# 24054  -122.310660  47.615378            2         0            0         2
# 82593  -122.300601  47.546379            5         0            0         2
#
#         WEATHER_Blowing Sand/Dirt  WEATHER_Clear  WEATHER_Fog/Smog/Smoke  \
# 9906                            0              0                       0
# 119351                          0              1                       0
# 75216                           0              1                       0
# 24054                           0              1                       0
# 82593                           0              1                       0
#
#         WEATHER_Overcast  ...  ROADCOND_Wet  \
# 9906                   0  ...             1
# 119351                 0  ...             0
# 75216                  0  ...             0
# 24054                  0  ...             0
# 82593                  0  ...             0
#
#         LIGHTCOND_Dark - No Street Lights  LIGHTCOND_Dark - Street Lights Off  \
# 9906                                    0                                   0
# 119351                                  0                                   0
# 75216                                   0                                   0
# 24054                                   0                                   0
# 82593                                   0                                   0
#
#         LIGHTCOND_Dark - Street Lights On  LIGHTCOND_Dark - Unknown Lighting  \
# 9906                                    1                                  0
# 119351                                  0                                  0
# 75216                                   0                                  0
# 24054                                   0                                  0
# 82593                                   0                                  0
#
#         LIGHTCOND_Dawn  LIGHTCOND_Daylight  LIGHTCOND_Dusk  UNDERINFL_N  \
# 9906                 0                   0               0            1
# 119351               0                   1               0            1
# 75216                0                   1               0            1
# 24054                0                   1               0            1
# 82593                0                   1               0            1
#
#         UNDERINFL_Y
# 9906              0
# 119351            0
# 75216             0
# 24054             0
# 82593             0
#
# [5 rows x 31 columns]
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 109428 entries, 9906 to 73787
# Data columns (total 31 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   X                                   109428 non-null  float64
#  1   Y                                   109428 non-null  float64
#  2   PERSONCOUNT                         109428 non-null  int64
#  3   PEDCOUNT                            109428 non-null  int64
#  4   PEDCYLCOUNT                         109428 non-null  int64
#  5   VEHCOUNT                            109428 non-null  int64
#  6   WEATHER_Blowing Sand/Dirt           109428 non-null  uint8
#  7   WEATHER_Clear                       109428 non-null  uint8
#  8   WEATHER_Fog/Smog/Smoke              109428 non-null  uint8
#  9   WEATHER_Overcast                    109428 non-null  uint8
#  10  WEATHER_Partly Cloudy               109428 non-null  uint8
#  11  WEATHER_Raining                     109428 non-null  uint8
#  12  WEATHER_Severe Crosswind            109428 non-null  uint8
#  13  WEATHER_Sleet/Hail/Freezing Rain    109428 non-null  uint8
#  14  WEATHER_Snowing                     109428 non-null  uint8
#  15  ROADCOND_Dry                        109428 non-null  uint8
#  16  ROADCOND_Ice                        109428 non-null  uint8
#  17  ROADCOND_Oil                        109428 non-null  uint8
#  18  ROADCOND_Sand/Mud/Dirt              109428 non-null  uint8
#  19  ROADCOND_Snow/Slush                 109428 non-null  uint8
#  20  ROADCOND_Standing Water             109428 non-null  uint8
#  21  ROADCOND_Wet                        109428 non-null  uint8
#  22  LIGHTCOND_Dark - No Street Lights   109428 non-null  uint8
#  23  LIGHTCOND_Dark - Street Lights Off  109428 non-null  uint8
#  24  LIGHTCOND_Dark - Street Lights On   109428 non-null  uint8
#  25  LIGHTCOND_Dark - Unknown Lighting   109428 non-null  uint8
#  26  LIGHTCOND_Dawn                      109428 non-null  uint8
#  27  LIGHTCOND_Daylight                  109428 non-null  uint8
#  28  LIGHTCOND_Dusk                      109428 non-null  uint8
#  29  UNDERINFL_N                         109428 non-null  uint8
#  30  UNDERINFL_Y                         109428 non-null  uint8
# dtypes: float64(2), int64(4), uint8(25)
# memory usage: 8.5 MB
# None

# %%
#Scaling training data as per the requirements
scaler = StandardScaler()
X_train[['X','Y','PERSONCOUNT','PEDCOUNT','PEDCYLCOUNT','VEHCOUNT']] = scaler.fit_transform(
    X_train[['X','Y','PERSONCOUNT','PEDCOUNT','PEDCYLCOUNT','VEHCOUNT']])

#Scaling test data as per the requirements
scaler = StandardScaler()
X_test[['X','Y','PERSONCOUNT','PEDCOUNT','PEDCYLCOUNT','VEHCOUNT']] = scaler.fit_transform(
    X_test[['X','Y','PERSONCOUNT','PEDCOUNT','PEDCYLCOUNT','VEHCOUNT']])

X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87542 entries, 54893 to 180734
# Data columns (total 31 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   X                                   87542 non-null  float64
#  1   Y                                   87542 non-null  float64
#  2   PERSONCOUNT                         87542 non-null  float64
#  3   PEDCOUNT                            87542 non-null  float64
#  4   PEDCYLCOUNT                         87542 non-null  float64
#  5   VEHCOUNT                            87542 non-null  float64
#  6   WEATHER_Blowing Sand/Dirt           87542 non-null  uint8
#  7   WEATHER_Clear                       87542 non-null  uint8
#  8   WEATHER_Fog/Smog/Smoke              87542 non-null  uint8
#  9   WEATHER_Overcast                    87542 non-null  uint8
#  10  WEATHER_Partly Cloudy               87542 non-null  uint8
#  11  WEATHER_Raining                     87542 non-null  uint8
#  12  WEATHER_Severe Crosswind            87542 non-null  uint8
#  13  WEATHER_Sleet/Hail/Freezing Rain    87542 non-null  uint8
#  14  WEATHER_Snowing                     87542 non-null  uint8
#  15  ROADCOND_Dry                        87542 non-null  uint8
#  16  ROADCOND_Ice                        87542 non-null  uint8
#  17  ROADCOND_Oil                        87542 non-null  uint8
#  18  ROADCOND_Sand/Mud/Dirt              87542 non-null  uint8
#  19  ROADCOND_Snow/Slush                 87542 non-null  uint8
#  20  ROADCOND_Standing Water             87542 non-null  uint8
#  21  ROADCOND_Wet                        87542 non-null  uint8
#  22  LIGHTCOND_Dark - No Street Lights   87542 non-null  uint8
#  23  LIGHTCOND_Dark - Street Lights Off  87542 non-null  uint8
#  24  LIGHTCOND_Dark - Street Lights On   87542 non-null  uint8
#  25  LIGHTCOND_Dark - Unknown Lighting   87542 non-null  uint8
#  26  LIGHTCOND_Dawn                      87542 non-null  uint8
#  27  LIGHTCOND_Daylight                  87542 non-null  uint8
#  28  LIGHTCOND_Dusk                      87542 non-null  uint8
#  29  UNDERINFL_N                         87542 non-null  uint8
#  30  UNDERINFL_Y                         87542 non-null  uint8
# dtypes: float64(6), uint8(25)
# memory usage: 6.8 MB
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
X.head()
# Out:
#                  X          Y  PERSONCOUNT  PEDCOUNT  PEDCYLCOUNT  VEHCOUNT  \
# 9906   -122.347301  47.645030            2         0            0         2
# 119351 -122.356906  47.728233            2         0            0         2
# 75216  -122.279013  47.526117            2         0            0         2
# 24054  -122.310660  47.615378            2         0            0         2
# 82593  -122.300601  47.546379            5         0            0         2
#
#         WEATHER_Blowing Sand/Dirt  WEATHER_Clear  WEATHER_Fog/Smog/Smoke  \
# 9906                            0              0                       0
# 119351                          0              1                       0
# 75216                           0              1                       0
# 24054                           0              1                       0
# 82593                           0              1                       0
#
#         WEATHER_Overcast  ...  ROADCOND_Wet  \
# 9906                   0  ...             1
# 119351                 0  ...             0
# 75216                  0  ...             0
# 24054                  0  ...             0
# 82593                  0  ...             0
#
#         LIGHTCOND_Dark - No Street Lights  LIGHTCOND_Dark - Street Lights Off  \
# 9906                                    0                                   0
# 119351                                  0                                   0
# 75216                                   0                                   0
# 24054                                   0                                   0
# 82593                                   0                                   0
#
#         LIGHTCOND_Dark - Street Lights On  LIGHTCOND_Dark - Unknown Lighting  \
# 9906                                    1                                  0
# 119351                                  0                                  0
# 75216                                   0                                  0
# 24054                                   0                                  0
# 82593                                   0                                  0
#
#         LIGHTCOND_Dawn  LIGHTCOND_Daylight  LIGHTCOND_Dusk  UNDERINFL_N  \
# 9906                 0                   0               0            1
# 119351               0                   1               0            1
# 75216                0                   1               0            1
# 24054                0                   1               0            1
# 82593                0                   1               0            1
#
#         UNDERINFL_Y
# 9906              0
# 119351            0
# 75216             0
# 24054             0
# 82593             0
#
# [5 rows x 31 columns]

# %%
missing_function(X_train)
print(X_train.info())
print(X_test.info())
# Out:
# X
# False    87542
# Name: X, dtype: int64
# -0.493157    142
#  0.072369    135
# -0.081465    133
# -0.496543    124
#  1.044832    116
#             ...
# -0.576663      1
#  1.910421      1
# -1.701407      1
#  0.500299      1
# -0.845769      1
# Name: X, Length: 17119, dtype: int64
#
# Y
# False    87542
# Name: Y, dtype: int64
#  1.709344    142
# -0.268786    135
#  1.560236    133
#  1.846966    124
# -0.697413    116
#             ...
# -1.256289      1
#  0.771347      1
#  0.859889      1
#  0.287715      1
#  0.988604      1
# Name: Y, Length: 17277, dtype: int64
#
# PERSONCOUNT
# False    87542
# Name: PERSONCOUNT, dtype: int64
# -0.393025     46864
#  0.303273     18315
#  0.999571      7922
# -1.089323      5139
#  1.695869      3635
# -1.785621      2779
#  2.392168      1544
#  3.088466       700
#  3.784764       311
#  4.481062       128
#  5.177360        75
#  5.873658        35
#  6.569956        23
#  7.962552        11
#  7.266254        10
#  10.051446        8
#  8.658850         6
#  9.355148         4
#  16.318129        3
#  11.444043        3
#  20.495918        2
#  19.103322        2
#  10.747745        2
#  15.621831        2
#  21.888514        2
#  14.229235        2
#  23.977408        2
#  17.014427        1
#  35.118177        1
#  25.370004        1
#  13.532937        1
#  12.836639        1
#  14.925533        1
#  26.762600        1
#  18.407023        1
#  54.614524        1
#  17.710725        1
#  31.636687        1
#  28.851495        1
#  28.155197        1
# Name: PERSONCOUNT, dtype: int64
#
# PEDCOUNT
# False    87542
# Name: PEDCOUNT, dtype: int64
# -0.241686     82472
#  3.766966      4889
#  7.775617       160
#  11.784269       17
#  15.792920        3
#  23.810223        1
# Name: PEDCOUNT, dtype: int64
#
# PEDCYLCOUNT
# False    87542
# Name: PEDCYLCOUNT, dtype: int64
# -0.217273    83560
#  4.515370     3945
#  9.248013       37
# Name: PEDCYLCOUNT, dtype: int64
#
# VEHCOUNT
# False    87542
# Name: VEHCOUNT, dtype: int64
#  0.072716     63890
# -1.557853     14737
#  1.703286      7021
#  3.333856      1316
#  4.964426       311
# -3.188423       149
#  6.594996        80
#  8.225566        24
#  11.486706        7
#  14.747845        4
#  9.856136         2
#  13.117276        1
# Name: VEHCOUNT, dtype: int64
#
# WEATHER_Blowing Sand/Dirt
# False    87542
# Name: WEATHER_Blowing Sand/Dirt, dtype: int64
# 0    87520
# 1       22
# Name: WEATHER_Blowing Sand/Dirt, dtype: int64
#
# WEATHER_Clear
# False    87542
# Name: WEATHER_Clear, dtype: int64
# 1    56235
# 0    31307
# Name: WEATHER_Clear, dtype: int64
#
# WEATHER_Fog/Smog/Smoke
# False    87542
# Name: WEATHER_Fog/Smog/Smoke, dtype: int64
# 0    87253
# 1      289
# Name: WEATHER_Fog/Smog/Smoke, dtype: int64
#
# WEATHER_Overcast
# False    87542
# Name: WEATHER_Overcast, dtype: int64
# 0    73647
# 1    13895
# Name: WEATHER_Overcast, dtype: int64
#
# WEATHER_Partly Cloudy
# False    87542
# Name: WEATHER_Partly Cloudy, dtype: int64
# 0    87538
# 1        4
# Name: WEATHER_Partly Cloudy, dtype: int64
#
# WEATHER_Raining
# False    87542
# Name: WEATHER_Raining, dtype: int64
# 0    70880
# 1    16662
# Name: WEATHER_Raining, dtype: int64
#
# WEATHER_Severe Crosswind
# False    87542
# Name: WEATHER_Severe Crosswind, dtype: int64
# 0    87530
# 1       12
# Name: WEATHER_Severe Crosswind, dtype: int64
#
# WEATHER_Sleet/Hail/Freezing Rain
# False    87542
# Name: WEATHER_Sleet/Hail/Freezing Rain, dtype: int64
# 0    87493
# 1       49
# Name: WEATHER_Sleet/Hail/Freezing Rain, dtype: int64
#
# WEATHER_Snowing
# False    87542
# Name: WEATHER_Snowing, dtype: int64
# 0    87168
# 1      374
# Name: WEATHER_Snowing, dtype: int64
#
# ROADCOND_Dry
# False    87542
# Name: ROADCOND_Dry, dtype: int64
# 1    62812
# 0    24730
# Name: ROADCOND_Dry, dtype: int64
#
# ROADCOND_Ice
# False    87542
# Name: ROADCOND_Ice, dtype: int64
# 0    87036
# 1      506
# Name: ROADCOND_Ice, dtype: int64
#
# ROADCOND_Oil
# False    87542
# Name: ROADCOND_Oil, dtype: int64
# 0    87514
# 1       28
# Name: ROADCOND_Oil, dtype: int64
#
# ROADCOND_Sand/Mud/Dirt
# False    87542
# Name: ROADCOND_Sand/Mud/Dirt, dtype: int64
# 0    87512
# 1       30
# Name: ROADCOND_Sand/Mud/Dirt, dtype: int64
#
# ROADCOND_Snow/Slush
# False    87542
# Name: ROADCOND_Snow/Slush, dtype: int64
# 0    87150
# 1      392
# Name: ROADCOND_Snow/Slush, dtype: int64
#
# ROADCOND_Standing Water
# False    87542
# Name: ROADCOND_Standing Water, dtype: int64
# 0    87495
# 1       47
# Name: ROADCOND_Standing Water, dtype: int64
#
# ROADCOND_Wet
# False    87542
# Name: ROADCOND_Wet, dtype: int64
# 0    63815
# 1    23727
# Name: ROADCOND_Wet, dtype: int64
#
# LIGHTCOND_Dark - No Street Lights
# False    87542
# Name: LIGHTCOND_Dark - No Street Lights, dtype: int64
# 0    86869
# 1      673
# Name: LIGHTCOND_Dark - No Street Lights, dtype: int64
#
# LIGHTCOND_Dark - Street Lights Off
# False    87542
# Name: LIGHTCOND_Dark - Street Lights Off, dtype: int64
# 0    87006
# 1      536
# Name: LIGHTCOND_Dark - Street Lights Off, dtype: int64
#
# LIGHTCOND_Dark - Street Lights On
# False    87542
# Name: LIGHTCOND_Dark - Street Lights On, dtype: int64
# 0    63918
# 1    23624
# Name: LIGHTCOND_Dark - Street Lights On, dtype: int64
#
# LIGHTCOND_Dark - Unknown Lighting
# False    87542
# Name: LIGHTCOND_Dark - Unknown Lighting, dtype: int64
# 0    87537
# 1        5
# Name: LIGHTCOND_Dark - Unknown Lighting, dtype: int64
#
# LIGHTCOND_Dawn
# False    87542
# Name: LIGHTCOND_Dawn, dtype: int64
# 0    86299
# 1     1243
# Name: LIGHTCOND_Dawn, dtype: int64
#
# LIGHTCOND_Daylight
# False    87542
# Name: LIGHTCOND_Daylight, dtype: int64
# 1    58580
# 0    28962
# Name: LIGHTCOND_Daylight, dtype: int64
#
# LIGHTCOND_Dusk
# False    87542
# Name: LIGHTCOND_Dusk, dtype: int64
# 0    84661
# 1     2881
# Name: LIGHTCOND_Dusk, dtype: int64
#
# UNDERINFL_N
# False    87542
# Name: UNDERINFL_N, dtype: int64
# 1    82708
# 0     4834
# Name: UNDERINFL_N, dtype: int64
#
# UNDERINFL_Y
# False    87542
# Name: UNDERINFL_Y, dtype: int64
# 0    82708
# 1     4834
# Name: UNDERINFL_Y, dtype: int64
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87542 entries, 54893 to 180734
# Data columns (total 31 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   X                                   87542 non-null  float64
#  1   Y                                   87542 non-null  float64
#  2   PERSONCOUNT                         87542 non-null  float64
#  3   PEDCOUNT                            87542 non-null  float64
#  4   PEDCYLCOUNT                         87542 non-null  float64
#  5   VEHCOUNT                            87542 non-null  float64
#  6   WEATHER_Blowing Sand/Dirt           87542 non-null  uint8
#  7   WEATHER_Clear                       87542 non-null  uint8
#  8   WEATHER_Fog/Smog/Smoke              87542 non-null  uint8
#  9   WEATHER_Overcast                    87542 non-null  uint8
#  10  WEATHER_Partly Cloudy               87542 non-null  uint8
#  11  WEATHER_Raining                     87542 non-null  uint8
#  12  WEATHER_Severe Crosswind            87542 non-null  uint8
#  13  WEATHER_Sleet/Hail/Freezing Rain    87542 non-null  uint8
#  14  WEATHER_Snowing                     87542 non-null  uint8
#  15  ROADCOND_Dry                        87542 non-null  uint8
#  16  ROADCOND_Ice                        87542 non-null  uint8
#  17  ROADCOND_Oil                        87542 non-null  uint8
#  18  ROADCOND_Sand/Mud/Dirt              87542 non-null  uint8
#  19  ROADCOND_Snow/Slush                 87542 non-null  uint8
#  20  ROADCOND_Standing Water             87542 non-null  uint8
#  21  ROADCOND_Wet                        87542 non-null  uint8
#  22  LIGHTCOND_Dark - No Street Lights   87542 non-null  uint8
#  23  LIGHTCOND_Dark - Street Lights Off  87542 non-null  uint8
#  24  LIGHTCOND_Dark - Street Lights On   87542 non-null  uint8
#  25  LIGHTCOND_Dark - Unknown Lighting   87542 non-null  uint8
#  26  LIGHTCOND_Dawn                      87542 non-null  uint8
#  27  LIGHTCOND_Daylight                  87542 non-null  uint8
#  28  LIGHTCOND_Dusk                      87542 non-null  uint8
#  29  UNDERINFL_N                         87542 non-null  uint8
#  30  UNDERINFL_Y                         87542 non-null  uint8
# dtypes: float64(6), uint8(25)
# memory usage: 6.8 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21886 entries, 184569 to 88993
# Data columns (total 31 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   X                                   21886 non-null  float64
#  1   Y                                   21886 non-null  float64
#  2   PERSONCOUNT                         21886 non-null  float64
#  3   PEDCOUNT                            21886 non-null  float64
#  4   PEDCYLCOUNT                         21886 non-null  float64
#  5   VEHCOUNT                            21886 non-null  float64
#  6   WEATHER_Blowing Sand/Dirt           21886 non-null  uint8
#  7   WEATHER_Clear                       21886 non-null  uint8
#  8   WEATHER_Fog/Smog/Smoke              21886 non-null  uint8
#  9   WEATHER_Overcast                    21886 non-null  uint8
#  10  WEATHER_Partly Cloudy               21886 non-null  uint8
#  11  WEATHER_Raining                     21886 non-null  uint8
#  12  WEATHER_Severe Crosswind            21886 non-null  uint8
#  13  WEATHER_Sleet/Hail/Freezing Rain    21886 non-null  uint8
#  14  WEATHER_Snowing                     21886 non-null  uint8
#  15  ROADCOND_Dry                        21886 non-null  uint8
#  16  ROADCOND_Ice                        21886 non-null  uint8
#  17  ROADCOND_Oil                        21886 non-null  uint8
#  18  ROADCOND_Sand/Mud/Dirt              21886 non-null  uint8
#  19  ROADCOND_Snow/Slush                 21886 non-null  uint8
#  20  ROADCOND_Standing Water             21886 non-null  uint8
#  21  ROADCOND_Wet                        21886 non-null  uint8
#  22  LIGHTCOND_Dark - No Street Lights   21886 non-null  uint8
#  23  LIGHTCOND_Dark - Street Lights Off  21886 non-null  uint8
#  24  LIGHTCOND_Dark - Street Lights On   21886 non-null  uint8
#  25  LIGHTCOND_Dark - Unknown Lighting   21886 non-null  uint8
#  26  LIGHTCOND_Dawn                      21886 non-null  uint8
#  27  LIGHTCOND_Daylight                  21886 non-null  uint8
#  28  LIGHTCOND_Dusk                      21886 non-null  uint8
#  29  UNDERINFL_N                         21886 non-null  uint8
#  30  UNDERINFL_Y                         21886 non-null  uint8
# dtypes: float64(6), uint8(25)
# memory usage: 1.7 MB
# None

# %%
from sklearn.metrics import classification_report, confusion_matrix
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
#Fitting and Predictions
lr = LogisticRegression(random_state = 0)
lr.fit(X_train,Y_train)
lr_predictions = lr.predict(X_test)

#Confusion Matrix
lr_cm = confusion_matrix(Y_test,lr_predictions)
print(lr_cm,'\n')

#Classification Report
lr_cr = classification_report(Y_test,lr_predictions)
print(lr_cr,'\n')

#Accuracy
acc = accuracy_score(Y_test,lr_predictions)
print(acc,'\n')
accDict = {}
accDict['LR'] = acc

#plot
plt.figure()
plot_confusion_matrix(lr_cm, classes=['Injury=1','Property Damage=0'],normalize= False,  title='Confusion matrix')
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# [[9131 1920]
#  [6196 4639]]
#
#               precision    recall  f1-score   support
#
#            1       0.60      0.83      0.69     11051
#            2       0.71      0.43      0.53     10835
#
#     accuracy                           0.63     21886
#    macro avg       0.65      0.63      0.61     21886
# weighted avg       0.65      0.63      0.61     21886
#
#
# 0.6291693319930549
#
# Confusion matrix, without normalization
# [[9131 1920]
#  [6196 4639]]

# %% [markdown]
# <h3> KNN </h3>

# %%
#KNN - neighbor
#Fitting and Predictions
knn = KNeighborsClassifier()
param_grid = {'n_neighbors':[54],'p':[2]}
          
knn1 = GridSearchCV(knn, param_grid , cv=5)
print('1')
knn1.fit(X_train,Y_train)
print('2')
knn_predictions = knn1.predict(X_test)

print('Best Hyperparameter KNN : ',knn1.best_params_)

#Confusion Matrix
knn_cm = confusion_matrix(Y_test,knn_predictions)
print(knn_cm,'\n')

#Classification Report
knn_cr = classification_report(Y_test,knn_predictions)
print(knn_cr,'\n')

#Accuracy
acc = accuracy_score(Y_test,knn_predictions)
print(acc,'\n')
accDict['KNN'] = acc

#plot
plt.figure()
plot_confusion_matrix(knn_cm, classes=['Injury=1','Property Damage=0'],normalize= False,  title='Confusion matrix')
# Out:
# 1

# %% [markdown]
# SVC

# %%
#SVC
#Fitting and Predictions
svc = SVC()
params = {'kernel':['linear','rbf'],'max_iter':[90],
          'random_state':[0]}
print('1')
svc1 = GridSearchCV(svc, param_grid=params)
print('2')
svc1.fit(X_train,Y_train)
print('3')
svc_predictions = svc1.predict(X_test)
print('Best Hyperparameter SVM : ',svc1.best_params_)

#Confusion Matrix
svc_cm=confusion_matrix(Y_test,svc_predictions)
print(svc_cm,'\n')

#Classification Report
svc_cr = classification_report(Y_test,svc_predictions)
print(svc_cr,'\n')

#Accuracy

acc = accuracy_score(Y_test,svc_predictions)
print(acc,'\n')
accDict['SVC'] = acc

#plot
plt.figure()
plot_confusion_matrix(svc_cm, classes=['Injury=1','Property Damage=0'],normalize= False,  title='Confusion matrix')

# %%
#Fitting and Predictions
dtc = DecisionTreeClassifier()
params = {'criterion':['gini', 'entropy'], 
          'random_state':[0]}
dtc1 = GridSearchCV(dtc, param_grid=params)
dtc1.fit(X_train,Y_train)
dtc_predictions = dtc1.predict(X_test)
print('Best Hyperparameter DTC : ',dtc1.best_params_)

#Confusion Matrix
dtc_cm=confusion_matrix(Y_test,dtc_predictions)
print(dtc_cm,'\n')

#Classification Report
dtc_cr = classification_report(Y_test,dtc_predictions)
print(dtc_cr,'\n')

#Accuracy
acc = accuracy_score(Y_test,dtc_predictions)
print(acc,'\n')
accDict['DTC'] = acc

#plot
plt.figure()
plot_confusion_matrix(dtc_cm, classes=['Injury=1','Property Damage=0'],normalize= False,  title='Confusion matrix')

# %%
accDict = sorted(accDict.items(), key=lambda x: x[1], reverse=True)
dict1 = {}
for elem in accDict:
    dict1[elem[0]] = elem[1]
Algorithms = dict1.keys()
Accuracy = dict1.values()
plt.figure(figsize=(10,10))
plt.bar(Algorithms, Accuracy)
plt.xlabel('Algorithms')
plt.yticks(np.arange(0,max(Accuracy)+0.1,0.05))
plt.ylabel('Accuracy')
plt.title('Accuracy Comparision - Classfication Algorithms')
plt.show()
